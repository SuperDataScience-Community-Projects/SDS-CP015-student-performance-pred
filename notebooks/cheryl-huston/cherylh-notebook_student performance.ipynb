# %%
# !pip install numpy pandas seaborn matplotlib

# %%
#Import the CSV Data as Pandas DataFrame
df = pd.read_csv('student-mat.csv')

# %%
#Show Top 5 Records
df.head()
# Out:
#                                                                                                                                                                                                                                         student-mat
# school sex age address famsize Pstatus Medu Fedu Mjob    Fjob     reason guardian traveltime studytime failures schoolsup famsup paid activities nursery higher internet romantic famrel freetime goout Dalc Walc health absences G1 G2          G3
# GP     F   18  U       GT3     A       4    4    at_home teacher  course mother   2          2         0        yes       no     no   no         yes     yes    no       no       4      3        4     1    1    3      6        5  6            6
#            17  U       GT3     T       1    1    at_home other    course father   1          2         0        no        yes    no   no         no      yes    yes      no       5      3        3     1    1    3      4        5  5            6
#            15  U       LE3     T       1    1    at_home other    other  mother   1          2         3        yes       no     yes  no         yes     yes    yes      no       4      3        2     2    3    3      10       7  8           10
#                        GT3     T       4    2    health  services home   mother   1          3         0        no        yes    yes  yes        yes     yes    yes      yes      3      2        2     1    1    5      2        15 14          15

# %%
#Shape of the dataset
df.shape
# Out:
# (396, 1)

# %%
#Check Missing values
df.isna().sum()
# Out:
# student-mat    0
# dtype: int64

# %%
#Check Duplicates
df.duplicated().sum()
# Out:
# np.int64(377)

# %%
#Check data types
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 396 entries, ('school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2') to ('MS', 'M', '19', 'U', 'LE3', 'T', '1', '1', 'other', 'at_home', 'course', 'father', '1', '1', '0', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', '3', '2', '3', '3', '3', '5', '5', '8', '9')
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student-mat  396 non-null    object
# dtypes: object(1)
# memory usage: 23.9+ KB

# %%
#Checking the number of unique values of each column
df.nunique()
# Out:
# student-mat    19
# dtype: int64

# %%
#Check statistics of data set
df.describe()
# Out:
#        student-mat
# count          396
# unique          19
# top             10
# freq            56

# %%
#Exploring Data
df.head()
# Out:
#                                                                                                                                                                                                                                         student-mat
# school sex age address famsize Pstatus Medu Fedu Mjob    Fjob     reason guardian traveltime studytime failures schoolsup famsup paid activities nursery higher internet romantic famrel freetime goout Dalc Walc health absences G1 G2          G3
# GP     F   18  U       GT3     A       4    4    at_home teacher  course mother   2          2         0        yes       no     no   no         yes     yes    no       no       4      3        4     1    1    3      6        5  6            6
#            17  U       GT3     T       1    1    at_home other    course father   1          2         0        no        yes    no   no         no      yes    yes      no       5      3        3     1    1    3      4        5  5            6
#            15  U       LE3     T       1    1    at_home other    other  mother   1          2         3        yes       no     yes  no         yes     yes    yes      no       4      3        2     2    3    3      10       7  8           10
#                        GT3     T       4    2    health  services home   mother   1          3         0        no        yes    yes  yes        yes     yes    yes      yes      3      2        2     1    1    5      2        15 14          15

# %%
print("Categories in 'school' variable:     ",end=" " )
print(df['school'].unique())

print("Categories in 'sex' variable:     ",end=" " )
print(df['sex'].unique())

print("Categories in 'age' variable:  ",end=" ")
print(df['age'].unique())
# Out:
# Categories in 'sex' variable:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       1 # print("Categories in 'school' variable:     ",end=" " )
#       2 # print(df['school'].unique())
#       4 print("Categories in 'sex' variable:     ",end=" " )
# ----> 5 print(df['sex'].unique())
#       7 print("Categories in 'age' variable:  ",end=" ")
#       8 print(df['age'].unique())
#
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'sex'

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 0 numerical features : []
#
# We have 1 categorical features : ['student-mat']

# %%
df.head(2)
# Out:
#                                                                                                                                                                                                                                        student-mat
# school sex age address famsize Pstatus Medu Fedu Mjob    Fjob    reason guardian traveltime studytime failures schoolsup famsup paid activities nursery higher internet romantic famrel freetime goout Dalc Walc health absences G1 G2          G3
# GP     F   18  U       GT3     A       4    4    at_home teacher course mother   2          2         0        yes       no     no   no         yes     yes    no       no       4      3        4     1    1    3      6        5  6            6

# %% [markdown]
# #Adding columns for "Total Score" and "Average"

# %%
df['total score'] = df['G1'] + df['G2'] + df['G3']
df['average'] = df['total score']/3
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'G1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['total score'] = df['G1'] + df['G2'] + df['G3']
#       2 df['average'] = df['total score']/3
#       3 df.head()
#
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Desktop/SDS-CP015-student-performance-pred/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'G1'
